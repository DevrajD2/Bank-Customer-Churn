# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing Data

# %%
df = pd.read_csv('Bank Churn.csv')
df
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 0             2    15647311         Hill          608     Spain  Female   41
# 1             4    15701354         Boni          699    France  Female   39
# 2             5    15737888     Mitchell          850     Spain  Female   43
# 3             7    15592531     Bartlett          822    France    Male   50
# 4             9    15792365           He          501    France    Male   44
# ...         ...         ...          ...          ...       ...     ...  ...
# 9995       9982    15672754     Burbidge          498   Germany    Male   42
# 9996       9983    15768163      Griffin          655   Germany  Female   46
# 9997       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9998       9998    15584532          Liu          709    France  Female   36
# 9999       9999    15682355    Sabbatini          772   Germany    Male   42
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Churn               10000 non-null  int64
#  14  Complain            10000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Churn                 0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
ax = sns.countplot(x = 'Churn', data = df)

ax.bar_label(ax.containers[0])
plt.title("No. of Customers Churned")
plt.show()

# %%
plt.figure(figsize = (3,4))
gb = df.groupby("Churn").agg({'Churn':"count"})
plt.pie(gb['Churn'], labels = gb.index, autopct = "%1.2f%%")
plt.title("Percentage of Customers Churned", fontsize = 10)
plt.show()

# %%
plt.figure(figsize = (4,4))
ax = sns.countplot(x = "Geography", data = df, hue = "Churn" )
ax.bar_label(ax.containers[0])
plt.title("Churned per Location")
plt.show()

# %%
plt.figure(figsize = (3,3))
sns.countplot(x = "Gender", data = df, hue = "Churn")
plt.title("Churn by Gender")
plt.show()

# %%
df.columns.values
# Out:
# array(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Churn', 'Complain',
#        'Satisfaction Score', 'Card Type', 'Point Earned'], dtype=object)

# %%
plt.figure(figsize = (4,4))
ax = sns.countplot(x = "IsActiveMember", data = df,)
ax.bar_label(ax.containers[0])
plt.title("Current active members")
plt.show()

# %%
plt.figure(figsize = (9,4))
sns.histplot(x = "EstimatedSalary", data = df, bins = 72,)
plt.show()

# %%
total_counts = df.groupby('Card Type')['Churn'].value_counts(normalize=True).unstack() * 100
fig, ax = plt.subplots(figsize=(4, 4))  
total_counts.plot(kind='bar', stacked=True, ax=ax, color=['#1f77b4', '#ff7f0e'])  # Customize colors if desired

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    ax.text(x + width / 2, y + height / 2, f'{height:.1f}%', ha='center', va='center')

plt.title('Churn by Card Type (Stacked Bar Chart)')
plt.xlabel('Card Type')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=0)
plt.legend(title='Churn', bbox_to_anchor = (0.9,0.9))  

plt.show()
